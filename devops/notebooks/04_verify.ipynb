# %%
# runs in Chameleon Jupyter environment
# Set your floating IP here — replace A.B.C.D
FLOATING_IP="A.B.C.D"

# %% [markdown]
# ## Section 1: Verify Kubernetes cluster health

# %%
# runs in Chameleon Jupyter environment
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get nodes -o wide'

# %%
# runs in Chameleon Jupyter environment
# All pods across the entire cluster
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pods -A'

# %% [markdown]
# All nodes should show `Ready`. All pods should show `Running`.
#
# ---
# ## Verify Immich
#
# **Start your screen recorder now for Video 1.**
# Run the cells below in order — this is your video script.

# %%
# Show Immich pods running in K8s
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pods -n immich'

# %%
# Show services and external IP
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get svc -n immich'

# %%
# Show pod details
# Replace immich-server-XXXXX with your actual pod name from the cell above
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP \
  'kubectl describe pod -l app=immich-server -n immich | tail -30'

# %%
# 
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP \
  'kubectl logs deploy/immich-server -n immich --tail=20'

# %% [markdown]
# ** **
#
# Open `http://A.B.C.D:2283` in your browser (replace A.B.C.D with your floating IP).
#
# 1. If first visit: create an admin account and log in
# 2. Show the main Immich photo timeline
# 3. Click Upload → upload 1–2 photos → show them appear
# 4. Make sure the URL bar showing the floating IP is visible
#
# **Stop recording for Video 1.**
#
# ---
# ## Section 3: Verify Platform Services
#
# **Start your screen recorder now for Video 2.**

# %%
# 
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pods -n immich-platform'

# %%
# 
# STATUS = Bound proves data persists across pod restarts
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pvc -n immich-platform'

# %%
# 
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get svc -n immich-platform'

# %%
# VIDEO 2 — Scene 4: MLflow logs
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP \
  'kubectl logs deploy/mlflow -n immich-platform --tail=20'

# %%
# VIDEO 2 — Scene 5: Prove persistence — delete MLflow pod and watch it restart
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP \
  'kubectl delete pod -l app=mlflow -n immich-platform'

# %%
# 
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP \
  'kubectl get pods -n immich-platform'

# %% [markdown]
# **VIDEO 2 — Scene 7: Open MLflow and MinIO in browser**
#
# 1. Open `http://A.B.C.D:8000` — MLflow UI loads → click **Models** tab
# 2. Open `http://A.B.C.D:9001` — MinIO console loads → log in → show the `mlflow-artifacts` bucket
# 3. Make sure the URL bar is visible in both tabs
#
#
#
# ---
# ## Section 4: Confirm persistent storage

# %%
# Show all PVCs across the cluster — STATUS must be Bound
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pvc -A'

# %%
# Show persistent volumes — RECLAIM POLICY = Retain means data survives pod deletion
ssh -o StrictHostKeyChecking=no cc@$FLOATING_IP 'kubectl get pv'

# %% [markdown]
# ---
# **Continue to `05_teardown.ipynb` after submitting your assignment.**
